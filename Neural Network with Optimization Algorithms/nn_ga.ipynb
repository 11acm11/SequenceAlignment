# %%
import random
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

df=pd.read_csv(r'C:\braindedmemory\SNU\COdes\ML tqns\EX9\Bank_Personal_Loan_Modelling.csv')
df['Experience']=abs(df['Experience'])
df['Annual_CCAvg']=df['CCAvg']*12
df.drop(['ID','ZIP Code','CCAvg'],axis=1,inplace=True)
X=df.drop('Personal Loan',axis=1).values
y=df['Personal Loan'].values.reshape(-1,1)
scaler = StandardScaler()
X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)


input_size = X_train.shape[1]
hidden_size = 5
output_size = 1

population_size = 30
mutation_rate = 0.1
generations = 500

def fitness(individual):
    W1 = np.array(individual[:input_size*hidden_size]).reshape((input_size, hidden_size))
    b1 = np.array(individual[input_size*hidden_size:input_size*hidden_size+hidden_size])
    W2 = np.array(individual[input_size*hidden_size+hidden_size:]).reshape((hidden_size, output_size))
    b2 = np.array([0.0])
    Z1 = np.dot(X_train, W1) + b1
    A1 = np.tanh(Z1)
    Z2 = np.dot(A1, W2) + b2
    y_pred = np.round(1 / (1 + np.exp(-Z2)))
    accuracy = np.sum(y_pred == y_train) / len(y_train)
    return accuracy

population = []
for i in range(population_size):
    individual = np.concatenate([np.random.randn(input_size*hidden_size), np.random.randn(hidden_size), np.random.randn(hidden_size*output_size)])
    population.append(individual)
for generation in range(generations):
    fitness_scores = [fitness(individual) for individual in population]
    parent1 = population[fitness_scores.index(max(fitness_scores))]
    parent2 = population[fitness_scores.index(sorted(fitness_scores)[-2])]
    offspring = []
    for i in range(population_size):
        child = []
        for j in range(len(parent1)):
            if random.random() < 0.5:
                child.append(parent1[j])
            else:
                child.append(parent2[j])
        for j in range(len(child)):
            if random.random() < mutation_rate:
                child[j] += np.random.randn()
        offspring.append(np.array(child))
    population = offspring
    print("Generation:", generation+1)
    print("Best fitness score:", max(fitness_scores))
best_individual = population[fitness_scores.index(max(fitness_scores))]
W1 = np.array(best_individual[:input_size*hidden_size]).reshape((input_size, hidden_size))
b1 = np.array(best_individual[input_size*hidden_size:input_size*hidden_size+hidden_size])
W2 = np.array(best_individual[input_size*hidden_size+hidden_size:]).reshape((hidden_size, output_size))
b2 = np.array([0.0])
Z1 = np.dot(X_test, W1) + b1
A1 =np.tanh(Z1)
Z2 = np.dot(A1, W2) + b2
y_pred = np.round(1 / (1 + np.exp(-Z2)))
accuracy = np.sum(y_pred == y_test) / len(y_test)
print("Test accuracy:", accuracy)
# Out:
# Generation: 1
# Best fitness score: 0.671
# Generation: 2
# Best fitness score: 0.79325
# Generation: 3
# Best fitness score: 0.831
# Generation: 4
# Best fitness score: 0.86175
# Generation: 5
# Best fitness score: 0.89325
# Generation: 6
# Best fitness score: 0.9005
# Generation: 7
# Best fitness score: 0.90575
# Generation: 8
# Best fitness score: 0.90975
# Generation: 9
# Best fitness score: 0.922
# Generation: 10
# Best fitness score: 0.93025
# Generation: 11
# Best fitness score: 0.935
# Generation: 12
# Best fitness score: 0.94125
# Generation: 13
# Best fitness score: 0.95075
# Generation: 14
# Best fitness score: 0.952
# Generation: 15
# Best fitness score: 0.9505
# Generation: 16
# Best fitness score: 0.9525
# Generation: 17
# Best fitness score: 0.95975
# Generation: 433
# Best fitness score: 0.96
# Generation: 434
# Best fitness score: 0.96
# Generation: 435
# Best fitness score: 0.96
# Generation: 436
# Best fitness score: 0.95975
# Generation: 437
# Best fitness score: 0.96
# Generation: 438
# Best fitness score: 0.96
# Generation: 439
# Best fitness score: 0.96
# Generation: 440
# Best fitness score: 0.96025
# Generation: 441
# Best fitness score: 0.9605
# Generation: 442
# Best fitness score: 0.96025
# Generation: 443
# Best fitness score: 0.9605
# Generation: 444
# Best fitness score: 0.9605
# Generation: 445
# Best fitness score: 0.96075
# Generation: 446
# Best fitness score: 0.9605
# Generation: 447
# Best fitness score: 0.96025
# Generation: 448
# Best fitness score: 0.9595
# Generation: 449
# Best fitness score: 0.96
# Generation: 450
# Best fitness score: 0.96025
# Generation: 451
# Best fitness score: 0.95975
# Generation: 452
# Best fitness score: 0.96
# Generation: 453
# Best fitness score: 0.96025
# Generation: 454
# Best fitness score: 0.9605
# Generation: 455
# Best fitness score: 0.96025
# Generation: 456
# Best fitness score: 0.9605
# Generation: 457
# Best fitness score: 0.96025
# Generation: 458
# Best fitness score: 0.96075
# Generation: 459
# Best fitness score: 0.9605
# Generation: 460
# Best fitness score: 0.9605
# Generation: 461
# Best fitness score: 0.96125
# Generation: 462
# Best fitness score: 0.961
# Generation: 463
# Best fitness score: 0.961
# Generation: 464
# Best fitness score: 0.96125
# Generation: 465
# Best fitness score: 0.96075
# Generation: 466
# Best fitness score: 0.96075
# Generation: 467
# Best fitness score: 0.96075
# Generation: 468
# Best fitness score: 0.9615
# Generation: 469
# Best fitness score: 0.96125
# Generation: 470
# Best fitness score: 0.962
# Generation: 471
# Best fitness score: 0.9615
# Generation: 472
# Best fitness score: 0.962
# Generation: 473
# Best fitness score: 0.9625
# Generation: 474
# Best fitness score: 0.962
# Generation: 475
# Best fitness score: 0.96175
# Generation: 476
# Best fitness score: 0.962
# Generation: 477
# Best fitness score: 0.96225
# Generation: 478
# Best fitness score: 0.962
# Generation: 479
# Best fitness score: 0.96225
# Generation: 480
# Best fitness score: 0.9625
# Generation: 481
# Best fitness score: 0.96225
# Generation: 482
# Best fitness score: 0.96225
# Generation: 483
# Best fitness score: 0.962
# Generation: 484
# Best fitness score: 0.962
# Generation: 485
# Best fitness score: 0.96275
# Generation: 486
# Best fitness score: 0.96225
# Generation: 487
# Best fitness score: 0.962
# Generation: 488
# Best fitness score: 0.96225
# Generation: 489
# Best fitness score: 0.96225
# Generation: 490
# Best fitness score: 0.962
# Generation: 491
# Best fitness score: 0.96175
# Generation: 492
# Best fitness score: 0.96125
# Generation: 493
# Best fitness score: 0.96025
# Generation: 494
# Best fitness score: 0.96125
# Generation: 495
# Best fitness score: 0.9615
# Generation: 496
# Best fitness score: 0.9605
# Generation: 497
# Best fitness score: 0.961
# Generation: 498
# Best fitness score: 0.9615
# Generation: 499
# Best fitness score: 0.9615
# Generation: 500
# Best fitness score: 0.96125
# Test accuracy: 0.951
